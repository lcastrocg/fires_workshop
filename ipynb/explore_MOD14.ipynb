# %%
#
# Purpose: to illustrate how to use netCDF4 methods built
#          in Python to get the information of a HDF4 file
# Author:  Lorena Castro
# Date  :  Jan. 24, 2017
#
# Read HDF file
#

#librarty needed to explore HDF4 files in python
from netCDF4 import Dataset

#
# See what is inside
#

# Open the HDF file
dir_data    = '../Data/'
filename = "MOD14.A2017001.1655.006.2017004111822.hdf"
hdf_file   = Dataset(dir_data+filename)

# %%
# reading the datasets and file attibutes in file
hdf_datasets = hdf_file.variables
hdf_attrs   = hdf_file.ncattrs()

# %%
# print No. of datasets and attributes
print ("No. of datasets :   ", len(hdf_datasets))
print ("No. of attributes : ", len(hdf_attrs))
# Out:
# No. of datasets :    30
# No. of attributes :  32

# %%
# print name of each  attribute
# enumerate create a list to iterate over it,
# this return and index and each element
for idx, attribute in enumerate(hdf_attrs):
    print ("File Attibute # ", idx, attribute)
# Out:
# File Attibute #  0 FirePix
# File Attibute #  1 LandFirePix
# File Attibute #  2 WaterFirePix
# File Attibute #  3 MissingPix
# File Attibute #  4 LandPix
# File Attibute #  5 WaterPix
# File Attibute #  6 CoastPix
# File Attibute #  7 WaterAdjacentFirePix
# File Attibute #  8 CloudAdjacentFirePix
# File Attibute #  9 UnknownLandPix
# File Attibute #  10 UnknownWaterPix
# File Attibute #  11 LandCloudPix
# File Attibute #  12 WaterCloudPix
# File Attibute #  13 GlintPix
# File Attibute #  14 GlintRejectedPix
# File Attibute #  15 CoastRejectedLandPix
# File Attibute #  16 HotSurfRejectedPix
# File Attibute #  17 ClearingRejectedPix
# File Attibute #  18 CoastRejectedWaterPix
# File Attibute #  19 DayPix
# File Attibute #  20 NightPix
# File Attibute #  21 MissingRadPix
# File Attibute #  22 MissingGeoPix
# File Attibute #  23 Satellite
# File Attibute #  24 ProcessVersionNumber
# File Attibute #  25 MOD021KM input file
# File Attibute #  26 MOD03 input file
# File Attibute #  27 SystemID
# File Attibute #  28 identifier_product_doi
# File Attibute #  29 identifier_product_doi_authority
# File Attibute #  30 CoreMetadata.0
# File Attibute #  31 ArchiveMetadata.0

# %%
# print name of each SDS and associated attributes
for idx, sds_name in enumerate(hdf_datasets):
    print  ('SDS No.', idx, hdf_datasets[sds_name].name)
    SDS_dimensions = hdf_datasets[sds_name].dimensions
    
    # reading an specific attribute of the SDS
    SDS_size = hdf_datasets[sds_name].shape
    
    # reading all the SDS attributes
    SDS_attributes = hdf_datasets[sds_name].ncattrs()
    
    # read and print dimension attributes
    for i in range(len(SDS_dimensions)):
        print ('Dim:', i, 'size:',SDS_size[i], 'name:', SDS_dimensions[i])
    
    # get and print SDS attribites
    for attr in SDS_attributes:
        print ('\tData Attribute:', attr)
    
    print('\n')
# Out:
# SDS No. 0 fire mask
# Dim: 0 size: 2030 name: number_of_scan_lines
# Dim: 1 size: 1354 name: pixels_per_scan_line
# 	Data Attribute: valid_range
# 	Data Attribute: legend
#
#
# SDS No. 1 algorithm QA
# Dim: 0 size: 2030 name: number_of_scan_lines
# Dim: 1 size: 1354 name: pixels_per_scan_line
# 	Data Attribute: units
#
#
# SDS No. 2 FP_line
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 3 FP_sample
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 4 FP_latitude
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 5 FP_longitude
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 6 FP_R2
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 7 FP_T21
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 8 FP_T31
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 9 FP_MeanT21
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 10 FP_MeanT31
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 11 FP_MeanDT
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 12 FP_MAD_T21
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 13 FP_MAD_T31
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 14 FP_MAD_DT
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 15 FP_power
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 16 FP_AdjCloud
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 17 FP_AdjWater
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 18 FP_WinSize
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 19 FP_NumValid
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 20 FP_confidence
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 21 FP_land
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 22 FP_MeanR2
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 23 FP_MAD_R2
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 24 FP_ViewZenAng
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 25 FP_SolZenAng
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 26 FP_RelAzAng
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
# 	Data Attribute: units
#
#
# SDS No. 27 FP_CMG_row
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 28 FP_CMG_col
# Dim: 0 size: 0 name: number_of_active_fires
# 	Data Attribute: long_name
#
#
# SDS No. 29 CMG_day
# Dim: 0 size: 9233 name: cmg_cells_day
# Dim: 1 size: 8 name: cmg_values
